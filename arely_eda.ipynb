# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
file_path = "data/Indicator_1_1_annual_6562429754166382300.csv"
df = pd.read_csv(file_path)

# %%
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing values:\n", df.isnull().sum())
print("\nUnique countries:", df['Country'].nunique())
print("\nUnique industries:", df['Industry'].nunique())
print("\nUnique gas types:", df['Gas Type'].nunique())
# Out:
# Shape: (1194, 28)
#
# Columns: ['ObjectId2', 'Country', 'ISO2', 'ISO3', 'Indicator', 'Unit', 'Source', 'CTS Code', 'CTS Name', 'CTS Full Descriptor', 'Industry', 'Gas Type', 'Seasonal Adjustment', 'Scale', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
#
# Missing values:
#  ObjectId2                 0
# Country                   0
# ISO2                   1194
# ISO3                      0
# Indicator                 0
# Unit                      0
# Source                    0
# CTS Code                  0
# CTS Name                  0
# CTS Full Descriptor       0
# Industry                  0
# Gas Type                  0
# Seasonal Adjustment       0
# Scale                     0
# 2010                      0
# 2011                      0
# 2012                      0
# 2013                      0
# 2014                      0
# 2015                      0
# 2016                      0
# 2017                      0
# 2018                      0
# 2019                      0
# 2020                      0
# 2021                      0
# 2022                      0
# 2023                      0
# dtype: int64
#
# Unique countries: 25
#
# Unique industries: 10
#
# Unique gas types: 5

# %%
df.head(3)
# Out:
#    ObjectId2             Country  ISO2   ISO3  \
# 0          1  Advanced Economies   NaN  AETMP
# 1          2  Advanced Economies   NaN  AETMP
# 2          3  Advanced Economies   NaN  AETMP
#
#                                            Indicator  \
# 0  Annual greenhouse gas (GHG) air emissions acco...
# 1  Annual greenhouse gas (GHG) air emissions acco...
# 2  Annual greenhouse gas (GHG) air emissions acco...
#
#                                     Unit  \
# 0  Million metric tons of CO2 equivalent
# 1  Million metric tons of CO2 equivalent
# 2  Million metric tons of CO2 equivalent
#
#                                               Source CTS Code  \
# 0  Organisation for Economic Co-operation and Dev...    ECNGA
# 1  Organisation for Economic Co-operation and Dev...    ECNGA
# 2  Organisation for Economic Co-operation and Dev...    ECNGA
#
#                                             CTS Name  \
# 0  Greenhouse Gas Emissions (GHG); Air Emissions ...
# 1  Greenhouse Gas Emissions (GHG); Air Emissions ...
# 2  Greenhouse Gas Emissions (GHG); Air Emissions ...
#
#                                  CTS Full Descriptor  \
# 0  Environment, Climate Change, Greenhouse Gas Em...
# 1  Environment, Climate Change, Greenhouse Gas Em...
# 2  Environment, Climate Change, Greenhouse Gas Em...
#
#                             Industry           Gas Type  Seasonal Adjustment  \
# 0  Agriculture, Forestry and Fishing     Carbon dioxide  Seasonally Adjusted
# 1  Agriculture, Forestry and Fishing  Fluorinated gases  Seasonally Adjusted
# 2  Agriculture, Forestry and Fishing     Greenhouse gas  Seasonally Adjusted
#
#    Scale         2010         2011         2012         2013         2014  \
# 0  Units   173.260853   170.220412   177.534807   175.325824   173.567963
# 1  Units     1.024105     1.089814     1.113030     1.193029     1.167994
# 2  Units  1323.978223  1315.166082  1313.348179  1356.224115  1366.936222
#
#           2015         2016         2017         2018         2019  \
# 0   177.091399   176.675451   178.385861   267.731429   264.950269
# 1     1.216524     1.177738     1.202901     1.078726     1.057855
# 2  1376.562102  1364.670233  1371.165410  1508.188585  1473.062889
#
#           2020         2021         2022         2023
# 0   259.339703   264.885635   263.950294   261.488111
# 1     1.056469     1.017692     0.986116     0.951482
# 2  1442.419245  1453.734142  1433.944153  1426.651170

# %%
for col in df.columns:
    if df[col].nunique() == 1:

        print(col)
    #df[df['Country'] == 'Advanced Economies'].head(10)
        print(df[col].nunique())
    #print(df[col].value_counts())
# Out:
# Indicator
# 1
# Unit
# 1
# Source
# 1
# CTS Code
# 1
# CTS Name
# 1
# CTS Full Descriptor
# 1
# Seasonal Adjustment
# 1
# Scale
# 1

# %%
df = df.drop(['ISO2','Indicator', 'Unit', 'Source', 'CTS Code', 'CTS Name','CTS Full Descriptor','Seasonal Adjustment', 'Scale'], axis = 1)

# %%
df['Gas Type'].value_counts()
# Out:
# Carbon dioxide       250
# Greenhouse gas       250
# Methane              250
# Nitrous oxide        250
# Fluorinated gases    194
# Name: Gas Type, dtype: int64

# %%
df.columns
# Out:
# Index(['ObjectId2', 'Country', 'ISO3', 'Industry', 'Gas Type', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %%
countries = df["Country"].unique()
print("Number of countries:", len(countries))
print(countries)
# Out:
# Number of countries: 25
# ['Advanced Economies' 'Africa' 'Americas' 'Asia'
#  'Australia and New Zealand' 'Central Asia' 'Eastern Asia'
#  'Eastern Europe' 'Emerging and Developing Economies' 'Europe' 'G20' 'G7'
#  'Latin America and the Caribbean' 'Northern Africa' 'Northern America'
#  'Northern Europe' 'Oceania' 'Other Oceania sub-regions'
#  'South-eastern Asia' 'Southern Asia' 'Southern Europe'
#  'Sub-Saharan Africa' 'Western Asia' 'Western Europe' 'World']

# %%
counts = (
    df["Country"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "Country", "Country": "Row_Count"})
)

print("Total unique regions:", len(counts))
counts
# Out:
# Total unique regions: 25
#                               Country  Row_Count
# 0                  Advanced Economies         50
# 1                              Europe         50
# 2                      Western Europe         50
# 3                        Western Asia         50
# 4                     Southern Europe         50
# 5                             Oceania         50
# 6                     Northern Europe         50
# 7                                  G7         50
# 8                                 G20         50
# 9                               World         50
# 10  Emerging and Developing Economies         50
# 11                     Eastern Europe         50
# 12                       Eastern Asia         50
# 13                       Central Asia         50
# 14          Australia and New Zealand         50
# 15                               Asia         50
# 16                   Northern America         45
# 17                           Americas         45
# 18    Latin America and the Caribbean         45
# 19                      Southern Asia         44
# 20                             Africa         43
# 21                    Northern Africa         43
# 22          Other Oceania sub-regions         43
# 23                 South-eastern Asia         43
# 24                 Sub-Saharan Africa         43

# %%
# Only want continents
df_continents = df[df['Country'].isin(['Asia', 'Africa', 'Europe', 'Oceania', 'Americas'])]
df_continents
# And then focus in on those with area of highest and break down even further
# Out:
#      ObjectId2  Country    ISO3  \
# 50          51   Africa   NA605
# 51          52   Africa   NA605
# 52          53   Africa   NA605
# 53          54   Africa   NA605
# 54          55   Africa   NA605
# ..         ...      ...     ...
# 816        936  Oceania  OCETMP
# 817        937  Oceania  OCETMP
# 818        938  Oceania  OCETMP
# 819        939  Oceania  OCETMP
# 820        940  Oceania  OCETMP
#
#                                               Industry           Gas Type  \
'2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %%
df[df['Country'] == 'Asia']
# Out:
#      ObjectId2 Country     ISO3  \
# 138        139    Asia  ASIATMP
# 139        140    Asia  ASIATMP
# 140        141    Asia  ASIATMP
# 141        142    Asia  ASIATMP
# 142        143    Asia  ASIATMP
# 143        144    Asia  ASIATMP
# 144        145    Asia  ASIATMP
# 145        146    Asia  ASIATMP
# 146        147    Asia  ASIATMP
# 147        148    Asia  ASIATMP
# 148        149    Asia  ASIATMP
# 149        150    Asia  ASIATMP
# 150        151    Asia  ASIATMP
# 151        152    Asia  ASIATMP
# 152        153    Asia  ASIATMP
# 153        154    Asia  ASIATMP
# 154        155    Asia  ASIATMP
# 155        156    Asia  ASIATMP
# 156        157    Asia  ASIATMP
# 157        158    Asia  ASIATMP
# 158        159    Asia  ASIATMP
# 159        160    Asia  ASIATMP
# 160        161    Asia  ASIATMP
# 161        281    Asia  ASIATMP
# 162        282    Asia  ASIATMP
# 163        283    Asia  ASIATMP
# 164        284    Asia  ASIATMP
# 165        285    Asia  ASIATMP
# 166        286    Asia  ASIATMP
# 167        287    Asia  ASIATMP
# 168        288    Asia  ASIATMP
# 169        289    Asia  ASIATMP
# 170        290    Asia  ASIATMP
# 171        291    Asia  ASIATMP
# 172        292    Asia  ASIATMP
# 173        293    Asia  ASIATMP
# 174        294    Asia  ASIATMP
# 175        295    Asia  ASIATMP
# 176        296    Asia  ASIATMP
# 177        297    Asia  ASIATMP
# 178        298    Asia  ASIATMP
# 179        299    Asia  ASIATMP
# 180        300    Asia  ASIATMP
# 181        301    Asia  ASIATMP
# 182        302    Asia  ASIATMP
# 183        303    Asia  ASIATMP
# 184        304    Asia  ASIATMP
# 185        305    Asia  ASIATMP
# 186        306    Asia  ASIATMP
# 187        307    Asia  ASIATMP
#
#                                               Industry           Gas Type  \
# 138                  Agriculture, Forestry and Fishing     Carbon dioxide
# 139                  Agriculture, Forestry and Fishing  Fluorinated gases
# 140                  Agriculture, Forestry and Fishing     Greenhouse gas
# 141                  Agriculture, Forestry and Fishing            Methane
# 142                  Agriculture, Forestry and Fishing      Nitrous oxide
# 143                                       Construction     Carbon dioxide
# 144                                       Construction  Fluorinated gases
# 145                                       Construction     Greenhouse gas
# 146                                       Construction            Methane
# 147                                       Construction      Nitrous oxide
# 148  Electricity, Gas, Steam and Air Conditioning S...     Carbon dioxide
# 149  Electricity, Gas, Steam and Air Conditioning S...  Fluorinated gases
# 150  Electricity, Gas, Steam and Air Conditioning S...     Greenhouse gas
# 151  Electricity, Gas, Steam and Air Conditioning S...            Methane
# 152  Electricity, Gas, Steam and Air Conditioning S...      Nitrous oxide
# 153                                      Manufacturing     Carbon dioxide
# 154                                      Manufacturing  Fluorinated gases
# 155                                      Manufacturing     Greenhouse gas
# 156                                      Manufacturing            Methane
# 157                                      Manufacturing      Nitrous oxide
# 158                                             Mining     Carbon dioxide
# 159                                             Mining  Fluorinated gases
# 160                                             Mining     Greenhouse gas
# 161                                             Mining            Methane
# 162                                             Mining      Nitrous oxide
# 163                          Other Services Industries     Carbon dioxide
# 164                          Other Services Industries  Fluorinated gases
# 165                          Other Services Industries     Greenhouse gas
# 166                          Other Services Industries            Methane
# 167                          Other Services Industries      Nitrous oxide
# 168                                   Total Households     Carbon dioxide
# 171     99.117414     96.292687     94.850537     96.271961
# 172     44.603892     46.474024     48.126113     50.579554
# 173  21909.462180  22949.772570  23062.406530  24087.896900
# 174    779.173878    822.711208    870.366015    914.554864
# 175  28481.449450  29681.200160  29999.586000  31179.582340
# 176   4678.195218   4782.654834   4931.567752   5020.855715
# 177   1114.618175   1126.061555   1135.245694   1156.274855
# 178   1846.555919   1934.780441   1995.285031   2156.903664
# 179     53.693371     56.615724     59.837381     63.061839
# 180   1973.154709   2065.917181   2131.578694   2299.752986
# 181     27.966293     27.969872     27.947489     28.387556
# 182     44.939126     46.551145     48.508793     51.399927
# 183    101.324783    107.033486    108.833020    112.370977
# 184      1.203026      1.217629      1.247701      1.269874
# 185    952.592209    979.150658    998.129119   1023.267224
# 186    780.660352    800.634796    816.734753    837.221870
# 187     69.404048     70.264747     71.313645     72.404503

# %%
#Compare industries

# %%
counts = (
    df["ISO3"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "ISO3", "ISO3": "Row_Count"})
)

print("Total unique regions:", len(counts))
counts
# Out:
# Total unique regions: 25
#        ISO3  Row_Count
# 0     AETMP         50
# 1    EURTMP         50
# 2      NAWE         50
# 3      NAWA         50
# 4      NASE         50
# 5    OCETMP         50
# 6      NANE         50
# 7     NA119         50
# 8     NA120         50
# 9       WLD         50
# 10  EMDETMP         50
# 11     NAEE         50
# 12    NA510         50
# 13     NACA         50
# 14    NAANZ         50
# 15  ASIATMP         50
# 16    NA225         45
# 17   AMETMP         45
# 18   LACTMP         45
# 19     NASA         44
# 20    NA605         43
# 21    NANA9         43
# 22   NAOOSR         43
# 23    NASEA         43
# 24      SSA         43

# %%
print("Indicators:", df["Indicator"].unique()[:3])
print("Gas types:", df["Gas Type"].unique())
print("Industries:", df["Industry"].unique()[:5])
# Out:
# Indicators: ['Annual greenhouse gas (GHG) air emissions accounts']
# Gas types: ['Carbon dioxide' 'Fluorinated gases' 'Greenhouse gas' 'Methane'
#  'Nitrous oxide']
# Industries: ['Agriculture, Forestry and Fishing' 'Construction'
#  'Electricity, Gas, Steam and Air Conditioning Supply' 'Manufacturing'
#  'Mining']

# %%
counts = (
    df["Industry"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "Industry", "Industry": "Row_Count"})
)

print("Total unique regions:", len(counts))
counts
# Out:
# Total unique regions: 10
#                                             Industry  Row_Count
# 0                                      Manufacturing        125
# 1                          Other Services Industries        125
# 2                      Total Industry and Households        125
# 3                         Transportation and Storage        120
# 4                                   Total Households        119
# 5                  Agriculture, Forestry and Fishing        116
# 6                                       Construction        116
# 7  Electricity, Gas, Steam and Air Conditioning S...        116
# 8                                             Mining        116
# 9  Water supply; sewerage, waste management and r...        116

# %%
counts = (
    df["Gas Type"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "Gas Type", "Gas Type": "Row_Count"})
)

print("Total unique regions:", len(counts))
counts
# Out:
# Total unique regions: 5
#             Gas Type  Row_Count
# 0     Carbon dioxide        250
# 1     Greenhouse gas        250
# 2            Methane        250
# 3      Nitrous oxide        250
# 4  Fluorinated gases        194
